# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import date

# %% [markdown]
# Attempts that didn't work... (note: won't work here because variables not read in, just moved here to clean up code)

# %%
#XXX testing how to get waterday shift on just single year, how does the lambda work?
test = ts(lambda x:waterday(x)) 
test

# %%
#JUST AN EXAMPLE, CAN DELETE ONCE GET LOOP WORKING
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)

for i in range(1960,1963):
    ax1.plot(ts['%s' % (i)],label=i) 

ax1.legend(loc=2)

# %% [markdown]
# EXAMPLES

# %%
#JUST AN EXAMPLE
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)


for i in range(1,15):
    ax1.plot(np.array([1,5])*i,label=i)

colormap = plt.cm.gist_ncar #nipy_spectral, Set1,Paired   
colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]
for i,j in enumerate(ax1.lines):
    j.set_color(colors[i])

ax1.legend(loc=2)

# %%
#for just a single year:
ts['1960']

# %%
#simple plot
ts.plot()
